# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %%
rent = pd.read_csv("FINAL_RENT.csv")
rent
# Out:
#      Unnamed: 0                   Name       Lat         Lon    Price
# 0             0          Kallang Place  1.317646  103.866298     3709
# 1             1        East Coast Road  1.308351  103.909011     4000
# 2             2        East Coast Road  1.308351  103.909011     4000
# 3             3          Eng Kong Park  1.280971  103.846897     4200
# 4             4  Jurong West Street 41  1.346570  103.725619     5000
# ..          ...                    ...       ...         ...      ...
# 138         138            Bukit Pasoh  1.278422  103.840986    25000
# 139         139             Telok Ayer  1.282367  103.848264    26000
# 140         140             Telok Ayer  1.282367  103.848264    26000
# 141         141            Bukit Pasoh  1.278422  103.840986    30000
# 142         142    Ang Mo Kio Avenue 8  1.364715  103.852144  4700000
#
# [143 rows x 5 columns]

# %%
# center to the mean of all points
m = folium.Map(location=rent[["Lat", "Lon"]].mean().to_list(), zoom_start=11)

# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in rent.iterrows():
    location = (r["Lat"], r["Lon"])
    folium.Marker(location=location,
                  popup = r['Name'] + '\n$' + str(r['Price']),
                  tooltip=r['Name'])\
    .add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_893c901884d0adca416432d746323186 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_893c901884d0adca416432d746323186&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_893c901884d0adca416432d746323186 = L.map(
#                 &quot;map_893c901884d0adca416432d746323186&quot;,
#                 {
#                     center: [1.3021905265734246, 103.84736702553977],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3867266b2f58998801656da07740a672 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_893c901884d0adca416432d746323186);
#
#
#             var marker_e0e3ec5cd8e494ded6dc65fd581b2295 = L.marker(
#                 [1.317646, 103.8662984],
#                 {}
#             ).addTo(map_893c901884d0adca416432d746323186);
#
#
#         var popup_3b95d39527c91c86da9782214dc875f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a46cd561bc72c89537c0b927b3a0713d = $(`&lt;div id=&quot;html_a46cd561bc72c89537c0b927b3a0713d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kallang Place $3709&lt;/div&gt;`)[0];
#                 popup_3b95d39527c91c86da9782214dc875f6.setContent(html_a46cd561bc72c89537c0b927b3a0713d);
#
#
#
#         marker_e0e3ec5cd8e494ded6dc65fd581b2295.bindPopup(popup_3b95d39527c91c86da9782214dc875f6)
#         ;
#
#
#
#
#             marker_e0e3ec5cd8e494ded6dc65fd581b2295.bindTooltip(
#                 `&lt;div&gt;
#                      Kallang Place
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3ce36961b54a53c53d4dd8fdc0822bfd = L.marker(
#                 [1.3083508, 103.9090106],
#                 {}
#             ).addTo(map_893c901884d0adca416432d746323186);
#
#
#         var popup_b9e8941c5e8a84b5222b28db61b8dca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c6af05ec9f1b0390cae05d7cea58066 = $(`&lt;div id=&quot;html_6c6af05ec9f1b0390cae05d7cea58066&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;East Coast Road $4000&lt;/div&gt;`)[0];
#                 popup_b9e8941c5e8a84b5222b28db61b8dca7.setContent(html_6c6af05ec9f1b0390cae05d7cea58066);
#
#
#
#         marker_3ce36961b54a53c53d4dd8fdc0822bfd.bindPopup(popup_b9e8941c5e8a84b5222b28db61b8dca7)
#         ;
#
#
#
#
#             marker_3ce36961b54a53c53d4dd8fdc0822bfd.bindTooltip(
#                 `&lt;div&gt;
#                      East Coast Road
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_94576783d1eb8cc6dc121ce097d35f8f = L.marker(
#                 [1.3083508, 103.9090106],
#                 {}
#             ).addTo(map_893c901884d0adca416432d746323186);
#
#
#         var popup_25e20a1bd8003a33b1330ef77f304bcd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6d561dc5eb02536650370a44146ee25 = $(`&lt;div id=&quot;html_f6d561dc5eb02536650370a44146ee25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;East Coast Road $4000&lt;/div&gt;`)[0];
#                 popup_25e20a1bd8003a33b1330ef77f304bcd.setContent(html_f6d561dc5eb02536650370a44146ee25);
#
#
#
#         marker_94576783d1eb8cc6dc121ce097d35f8f.bindPopup(popup_25e20a1bd8003a33b1330ef77f304bcd)
#         ;
#
#
#
#
#             marker_94576783d1eb8cc6dc121ce097d35f8f.bindTooltip(
#                 `&lt;div&gt;
#                      East Coast Road
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2a87e5475c4f2102ee5c4d6771f65918 = L.marker(
#                 [1.2809705999999998, 103.84689714882104],
#                 {}
#             ).addTo(map_893c901884d0adca416432d746323186);
#
#
#         var popup_ede9d1c70420dea55203335891b135c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbdcb18d847c1c8769026a328ccab6cb = $(`&lt;div id=&quot;html_cbdcb18d847c1c8769026a328ccab6cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eng Kong Park $4200&lt;/div&gt;`)[0];
#                 popup_ede9d1c70420dea55203335891b135c0.setContent(html_cbdcb18d847c1c8769026a328ccab6cb);
#
#
#
#         marker_2a87e5475c4f2102ee5c4d6771f65918.bindPopup(popup_ede9d1c70420dea55203335891b135c0)
#         ;
#
#
#
#
#             marker_2a87e5475c4f2102ee5c4d6771f65918.bindTooltip(
#                 `&lt;div&gt;
#                      Eng Kong Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_95bc561515af8c8ebb6714cc03

# %%
m.save("folium_map_rent.html")
